# %% [markdown]
# # Preprocessing

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv("world-happiness-report.csv")
df = df[df['Country name'] == 'United States']

# %%
df.head()
# Out:
#        Country name  year  Life Ladder  Log GDP per capita  Social support  \
# 1836  United States  2006        7.182              10.924           0.965
# 1837  United States  2007        7.513              10.933             NaN
# 1838  United States  2008        7.280              10.922           0.953
# 1839  United States  2009        7.158              10.888           0.912
# 1840  United States  2010        7.164              10.905           0.926
#
#       Healthy life expectancy at birth  Freedom to make life choices  \
# 1836                             68.06                         0.911
# 1837                             68.22                         0.872
# 1838                             68.38                         0.878
# 1839                             68.54                         0.831
# 1840                             68.70                         0.828
#
#       Generosity  Perceptions of corruption  Positive affect  Negative affect
# ...

# %% [markdown]
# # Correlation Matrix

# %%
# Create correlation heat map
sns.heatmap(df.corr().round(2), cmap="Wistia", annot=True)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Happiness

# %% [markdown]
# ### Happiness vs. time

# %%
# Plot graph of happiness over time
ax = sns.regplot(x="year", y="Life Ladder", data=df, line_kws={'color':'red'})
ax.set_title("US happiness rating, 2006-2020")
# Out:
# Text(0.5, 1.0, 'US happiness rating, 2006-2020')

# %% [markdown]
# # Log GDP per capita

# %% [markdown]
# ### Log GDP per capita vs. time

# %%
# Plot graph of Log GDP per capita over time
ax = sns.regplot(x="year", y="Log GDP per capita", data=df, line_kws={'color':'red'})
ax.set_title("US log GDP per capita, 2006-2020")
# Out:
# Text(0.5, 1.0, 'US log GDP per capita, 2006-2020')

# %% [markdown]
# ### Happiness vs. Log GDP per capita

# %%
# Plot graph of Happiness rating versus Log GDP per capita
ax = sns.regplot(x="Log GDP per capita", y="Life Ladder", data=df, line_kws={'color':'red'})
ax.set_title("US happiness rating vs log GDP per capita, 2006-2020")
# Out:
# Text(0.5, 1.0, 'US happiness rating vs log GDP per capita, 2006-2020')

# %% [markdown]
# # Social Support

# %% [markdown]
# ### Social support vs. time

# %%
# Plot graph of happiness over time
ax = sns.regplot(x="year", y="Social support", data=df, line_kws={'color':'red'})
ax.set_title("US social support, 2006-2020")
# Out:
# Text(0.5, 1.0, 'US social support from 2006-2020')

# %% [markdown]
# ### Happiness vs. social support

# %%
# Plot graph of happiness over time
ax = sns.regplot(x="Social support", y="Life Ladder", data=df, line_kws={'color':'red'})
ax.set_title("US happiness rating vs. social support, 2006-2020")
# Out:
# Text(0.5, 1.0, 'US happiness rating vs. social support, 2006-2020')

# %% [markdown]
# # Freedom to make life choices

# %% [markdown]
# ### Freedom to make life choices vs. time

# %%
ax = sns.regplot(x="year", y="Freedom to make life choices", data=df, line_kws={'color':'red'})
ax.set_title("US freedom to make life choices, 2006-2020")
# Out:
# Text(0.5, 1.0, 'US freedom to make life choices from 2006-2020')

# %% [markdown]
# ### Happiness vs. Freedom to make life choices

# %%
ax = sns.regplot(x="Perceptions of corruption", y="Life Ladder", data=df, line_kws={'color':'red'})
ax.set_title("US happiness vs. freedom to make life choices, 2006-2020")
# Out:
# Text(0.5, 1.0, 'US happiness vs. freedom to make life choices, 2006-2020')

# %% [markdown]
# # Generosity

# %% [markdown]
# ### Generosity vs. time

# %%
ax = sns.regplot(x="year", y="Generosity", data=df, line_kws={'color':'red'})
ax.set_title("US generosity, 2006-2020")
# Out:
# Text(0.5, 1.0, 'US generosity from 2006-2020')

# %% [markdown]
# ### Happiness vs. generosity

# %%
ax = sns.regplot(x="Generosity", y="Life Ladder", data=df, line_kws={'color':'red'})
ax.set_title("Happiness vs. Generosity, 2006-2020")
# Out:
# Text(0.5, 1.0, 'Happiness vs. Generosity, 2006-2020')

# %% [markdown]
# # Perception of corruption

# %% [markdown]
# ### Perception of corruption vs. time

# %%
ax = sns.regplot(x="year", y="Perceptions of corruption", data=df, line_kws={'color':'red'})
ax.set_title("US perceptions of corruption, 2006-2020")
# Out:
# Text(0.5, 1.0, 'US perceptions of corruption from 2006-2020')

# %% [markdown]
# ### Happiness vs. perception of corruption

# %%
ax = sns.regplot(x="Perceptions of corruption", y="Life Ladder", data=df, line_kws={'color':'red'})
ax.set_title("US perceptions of corruption vs. happiness, 2006-2020")
# Out:
# Text(0.5, 1.0, 'US perceptions of corruption vs. happiness, 2006-2020')

# %% [markdown]
# # Summary

# %% [markdown]
# Over time, the things that make the US a happier country (social support, freedom, generosity) have been decreasing
#
# Meanwhile, the things that make the US a less happier country (higher log GDP/capita, perceptions of corruption) have been increasing
#
# The negative association between happiness and log GDP/capita is particularly intriguing - what are some possible reasons for this?
# * Inflation
# * Uneven distribution of the GDP → greater perceptions of corruption?
# * More time spent working → worse health/life expectancy?
#     * Sounds intuitive, but health/life expectancy is surprisingly uncorrelated with happiness...

# %% [markdown]
# # References

# %% [markdown]
# Singh, A. (March, 2021). World Happiness Report 2021, Version 2. Retrieved December 14, 2021 from
#     https://www.kaggle.com/ajaypalsinghlo/world-happiness-report-2021
